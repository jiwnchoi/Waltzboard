# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from vega_datasets import data
from src.space.DataModel import Attribute

from src.oracle import ColumbusProbOracle, OracleWeight
from src.ProbColumbus import (
    ProbColumbus,
    ColumbusConfig,
    SamplingWeight,
    chart_type,
    agg_type,
    ProbabilisticNode,
)

df = data.movies()
name_attrs = [
    col
    for col in df.columns
    if (df[col].dtype == "object" and df[col].nunique() < 10)
    or df[col].dtype != "object"
]
dic = {col: "C" if df[col].dtype == "object" else "Q" for col in df.columns}
dic[None] = None

df = df[name_attrs]
attrs = [None] + name_attrs
chart_type
# Out:
# ['bar', 'point', 'arc', 'rect', 'tick', 'boxplot']

# %%
oracle_weight = OracleWeight(
    specificity=1.0,
    uniqueness=1.0,
    coverage=1.0,
    interestingness=1.0,
)
oracle = ColumbusProbOracle(oracle_weight)
prob = ProbColumbus(df, ColumbusConfig())

# %%
from IPython.display import clear_output
from collections import Counter
import altair as alt

n_epoch = 1000
n_dashboards = 100
halving = 0.1

means = []
maxs = []

conjugate_priors = SamplingWeight(
    x=np.ones(len(attrs)-1),
    y=np.ones(len(attrs)),
    z=np.ones(len(attrs)),
    ct=np.ones(len(chart_type)),
    at=np.ones(len(agg_type)),
    attr=attrs,
    chart_type=chart_type,
    agg_type=agg_type,
)

def mean(l):
    return sum(l) / len(l)

for epoch in range(n_epoch):
    
    candidate: list = [prob._sample_n(10, conjugate_priors) for _ in range(n_dashboards)]
    scores: list[float] = [prob._infer(dashboard, oracle, ["IMDB_Votes", "rect"]) for dashboard in candidate]
    candi_n_score = list(zip(candidate, scores))
    candi_n_score = sorted(candi_n_score, key=lambda x: x[1], reverse=True)
    
    
    means.append(mean(scores))
    maxs.append(max(scores))
    
    # halving
    halved_candidate = candi_n_score[: int(n_dashboards * halving)]
    
    counters = [Counter() for _ in range(5)]
    counters[0][None] = 0
    counters[1][None] = 0
    counters[2][None] = 0
    
    for dashboard in halved_candidate:
        for chart in dashboard[0]:
            for i in range(3):
                if chart[i] is None:
                    counters[i][None] += 1
                elif chart[i].name in counters[i]:
                    counters[i][chart[i].name] += 1
                else:
                    counters[i][chart[i].name] = 1

            for i in [3,4]:
                if chart[i] in counters[i]:
                    counters[i][chart[i]] += 1
                else:
                    counters[i][chart[i]] = 1
    
    # update conjucate prior with liklihood by counter
    x = np.array([counters[0][attr] for attr in attrs[1:]])
    y = np.array([counters[1][attr] for attr in attrs])
    z = np.array([counters[2][attr] for attr in attrs])
    ct = np.array([counters[3][c] for c in chart_type])
    at = np.array([counters[4][a] for a in agg_type])
    
    conjugate_priors.x += x
    conjugate_priors.y += y
    conjugate_priors.z += z
    conjugate_priors.ct += ct
    conjugate_priors.at += at
    
    # visualize mean and max using altair
    data = pd.DataFrame({"epoch": range(epoch+1), "mean": means, "max": maxs})
    line = alt.Chart(data).mark_line().encode(
        x="epoch",
    )
    clear_output(wait=True)
    print(f"Epoch {epoch}")
    display(line.encode(y=alt.Y("mean", scale=alt.Scale(zero=False))) | line.encode(y=alt.Y("max",scale=alt.Scale(zero=False))))
# Out:
# Epoch 74
# alt.HConcatChart(...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 29
#      26 for epoch in range(n_epoch):
#      28     candidate: list = [prob._sample_n(10, conjugate_priors) for _ in range(n_dashboards)]
# ---> 29     scores: list[float] = [prob._infer(dashboard, oracle, ["IMDB_Votes", "rect"]) for dashboard in candidate]
#      30     candi_n_score = list(zip(candidate, scores))
#      31     candi_n_score = sorted(candi_n_score, key=lambda x: x[1], reverse=True)
#
# Cell In[19], line 29, in <listcomp>(.0)
#      26 for epoch in range(n_epoch):
#      28     candidate: list = [prob._sample_n(10, conjugate_priors) for _ in range(n_dashboards)]
# ---> 29     scores: list[float] = [prob._infer(dashboard, oracle, ["IMDB_Votes", "rect"]) for dashboard in candidate]
#      30     candi_n_score = list(zip(candidate, scores))
#      31     candi_n_score = sorted(candi_n_score, key=lambda x: x[1], reverse=True)
#
# File ~/git/columbus/src/ProbColumbus.py:170, in ProbColumbus._infer(self, samples, oracle, wildcard)
#     163 def _infer(
#     164     self,
#     165     samples: list[str],
#     166     oracle: ColumbusProbOracle,
#     167     wildcard: list[str],
#     168 ):
#     169     nodes = [ProbabilisticNode(sample, self.df) for sample in samples]
# --> 170     result = oracle.get_result(nodes, self.df, set(wildcard))
#     171     return float(result.get_score())
#
# File ~/git/columbus/src/oracle/ColumbusOracle.py:106, in ColumbusProbOracle.get_result(self, nodes, df, wildcard)
#      99 def get_result(
#     100     self, nodes: list["ProbabilisticNode"], df: pd.DataFrame, wildcard: set[str]
#     101 ) -> OracleResult:
#     102     return OracleResult(
#     103         weight=self.weight,
#     104         coverage=get_coverage_from_nodes(nodes, df),
#     105         uniqueness=get_uniqueness_from_nodes(nodes),
# --> 106         interestingness=get_interestingness_v2(nodes),
#     107         specificity=get_specificity_from_nodes(nodes, wildcard),
#     108     )
#
# File ~/git/columbus/src/oracle/Interestingness.py:232, in get_interestingness_v2(nodes)
#     229 def get_interestingness_v2(
#     230     nodes: list["VisualizationNode"] | list["ProbabilisticNode"],
#     231 ) -> float:
# --> 232     node_features = [get_statistic_features_v2(node) for node in nodes]
#     233     return mean([get_interestingness(feature) for feature in node_features])
#
# File ~/git/columbus/src/oracle/Interestingness.py:232, in <listcomp>(.0)
#     229 def get_interestingness_v2(
#     230     nodes: list["VisualizationNode"] | list["ProbabilisticNode"],
#     231 ) -> float:
# --> 232     node_features = [get_statistic_features_v2(node) for node in nodes]
#     233     return mean([get_interestingness(feature) for feature in node_features])
#
# File ~/git/columbus/src/oracle/Interestingness.py:192, in get_statistic_features_v2(node)
#     189 target_attrs = [attr.name for attr in comb]
#     190 key += f"{target_attrs}"
# --> 192 df_notnull = node.sub_df.dropna()
#     193 try:
#     194     if key not in hashmap:
#
# File ~/miniforge3/envs/columbus/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/columbus/lib/python3.10/site-packages/pandas/core/frame.py:6569, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6566     mask = count >= thresh
#    6567 elif how == "any":
#    6568     # faster equivalent to 'agg_obj.count(agg_axis) == self.shape[agg_axis]'
# -> 6569     mask = notna(agg_obj).all(axis=agg_axis, bool_only=False)
#    6570 elif how == "all":
#    6571     # faster equivalent to 'agg_obj.count(agg_axis) > 0'
#    6572     mask = notna(agg_obj).any(axis=agg_axis, bool_only=False)
#
# File ~/miniforge3/envs/columbus/lib/python3.10/site-packages/pandas/core/generic.py:11629, in NDFrame._add_numeric_operations.<locals>.all(self, axis, bool_only, skipna, level, **kwargs)
#   11618 @doc(
#   11619     _bool_doc,
#   11620     desc=_all_desc,
#    (...)
#   11627 )
#   11628 def all(self, axis=0, bool_only=None, skipna=True, level=None, **kwargs):
# > 11629     return NDFrame.all(self, axis, bool_only, skipna, level, **kwargs)
#
# File ~/miniforge3/envs/columbus/lib/python3.10/site-packages/pandas/core/generic.py:11186, in NDFrame.all(self, axis, bool_only, skipna, level, **kwargs)
#   11178 def all(
#   11179     self,
#   11180     axis: Axis = 0,
#    (...)
#   11184     **kwargs,
#   11185 ) -> Series | bool_t:
# > 11186     return self._logical_func(
#   11187         "all", nanops.nanall, axis, bool_only, skipna, level, **kwargs
#   11188     )
#
# File ~/miniforge3/envs/columbus/lib/python3.10/site-packages/pandas/core/generic.py:11155, in NDFrame._logical_func(self, name, func, axis, bool_only, skipna, level, **kwargs)
#   11153     if bool_only:
#   11154         obj = self._get_bool_data()
# > 11155     return obj._reduce_axis1(name, func, skipna=skipna)
#   11157 return self._reduce(
#   11158     func,
#   11159     name=name,
#    (...)
#   11163     filter_type="bool",
#   11164 )
#
# File ~/miniforge3/envs/columbus/lib/python3.10/site-packages/pandas/core/frame.py:10942, in DataFrame._reduce_axis1(self, name, func, skipna)
#   10939     middle = func(arr, axis=0, skipna=skipna)
#   10940     result = ufunc(result, middle)
# > 10942 res_ser = self._constructor_sliced(result, index=self.index)
#   10943 return res_ser
#
# File ~/miniforge3/envs/columbus/lib/python3.10/site-packages/pandas/core/series.py:483, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     481     object.__setattr__(self, "_name", name)
#     482 else:
# --> 483     self.name = name
#     484     self._set_axis(0, index)
#
# File ~/miniforge3/envs/columbus/lib/python3.10/site-packages/pandas/core/generic.py:5921, in NDFrame.__setattr__(self, name, value)
#    5917     pass
#    5919 # if this fails, go on to more involved attribute setting
#    5920 # (note that this matches __getattr__, above).
# -> 5921 if name in self._internal_names_set:
#    5922     object.__setattr__(self, name, value)
#    5923 elif name in self._metadata:
#
# KeyboardInterrupt:
