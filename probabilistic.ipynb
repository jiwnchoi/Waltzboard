# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd 
from vega_datasets import data
from src.space.DataModel import Attribute

df = data.movies()

# name attributes
name_attrs = [
    col
    for col in df.columns    
    if (df[col].dtype == "object" and df[col].nunique() < 10) or df[col].dtype != "object"
]
dic = {
    col: "C" if df[col].dtype == "object" else "Q"
    for col in df.columns
}
dic[None] = None

df = df[name_attrs]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   US_Gross                3194 non-null   float64
#  1   Worldwide_Gross         3194 non-null   float64
#  2   US_DVD_Sales            564 non-null    float64
#  3   Production_Budget       3200 non-null   float64
#  4   MPAA_Rating             2596 non-null   object
#  5   Running_Time_min        1209 non-null   float64
#  6   Creative_Type           2755 non-null   object
#  7   Rotten_Tomatoes_Rating  2321 non-null   float64
#  8   IMDB_Rating             2988 non-null   float64
#  9   IMDB_Votes              2988 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 250.2+ KB

# %%
from src.oracle import ColumbusProbOracle, OracleWeight
from src.ProbColumbus import ProbColumbus, ColumbusConfig, SamplingWeight, chart_type, agg_type, ProbabilisticNode

oracle_weight = OracleWeight(
                             specificity=1.0,
                             uniqueness=1.0,
                             coverage=1.0,
                             interestingness=1.0,
                             )
oracle = ColumbusProbOracle(oracle_weight)
prob = ProbColumbus(df, ColumbusConfig())
print(len(chart_type), len(agg_type))
# def func(weight, n_samples, n_dashboards):   
#     dashboards = [
#         prob.sample_max_n(n_samples, weight)
#         for _ in range(n_dashboards)
#     ]
#     scores = [prob.infer(dashboard, oracle, ["attr_IMDB_Votes", "rect"]) for dashboard in dashboards]
#     print(np.max(scores), np.mean(scores))
#     sc = np.mean(scores)
#     return -sc


# def func_max(weight, n_samples):
#     dashboard = prob.sample_max_n(n_samples, weight)
#     score = prob.infer(dashboard, oracle, ["attr_IMDB_Votes", "rect"])
#     print(score)
#     return -score
# Out:
# 6 6

# %%
from skopt.space import Categorical, Space
from skopt import Optimizer
from skopt.utils import use_named_args
from src.ChartMap import chart_map
from tqdm import tqdm
import json


EPOCH = 50
NUM_CHARTS = 6

attrs = [None] + name_attrs

opt_space = Space([
    Categorical(attrs[1:], name="x"),
    Categorical(attrs, name="y"),
    Categorical(attrs, name="z"),
    Categorical(chart_type, name="ct"),
    Categorical(agg_type, name="at")
])

all_space = [(x, y, z, ct, at) for x in attrs[1:] for y in attrs for z in attrs for ct in chart_type for at in agg_type]
# filter all_space using chart_map
filtered_space = []

chart_map = set([tuple(chart) for chart in chart_map])

for x in tqdm(all_space):
    checker = tuple([dic[attr] for attr in x[:3]] + [x[3], x[4]])
    for chart in chart_map:
        if checker in chart_map and len(x) == len(set(x)):
            filtered_space.append(json.dumps(x))
            break
# Out:
# 100%|██████████| 43560/43560 [00:00<00:00, 372390.08it/s]

# %%
space = Space([
    Categorical(filtered_space, name=f"chart{i}") for i in range(NUM_CHARTS)
])

opt_dashboard = Optimizer(space, "gp", n_initial_points=10, acq_optimizer="auto")


for i in range(200):
    x = opt_dashboard.ask()
    x_loads = [json.loads(x_) for x_ in x]
    x_nodes = [prob.get_node(x_) for x_ in x_loads]
    print(x_loads)
    score = prob.infer(x_nodes, oracle, ["attr_IMDB_Votes", "rect"])
    opt_dashboard.tell(x, -score)

opt_dashboard.get_result()
# Out:
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Rating', 'IMDB_Votes', 'Running_Time_min', 'rect', 'mean'], ['IMDB_Votes', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'point', None], ['US_DVD_Sales', 'US_Gross', 'Worldwide_Gross', 'rect', 'mean'], ['Production_Budget', 'Worldwide_Gross', 'US_DVD_Sales', 'rect', 'mean'], ['US_Gross', 'IMDB_Votes', 'Production_Budget', 'point', None]]
# [['Worldwide_Gross', 'US_DVD_Sales', 'IMDB_Votes', 'rect', 'mean'], ['IMDB_Votes', 'Rotten_Tomatoes_Rating', 'Running_Time_min', 'rect', 'mean'], ['IMDB_Rating', 'US_Gross', 'Production_Budget', 'rect', 'max'], ['IMDB_Votes', 'IMDB_Rating', 'US_DVD_Sales', 'point', None], ['Creative_Type', 'US_DVD_Sales', None, 'arc', 'max'], ['US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'point', None]]
# [['US_Gross', 'Worldwide_Gross', 'Production_Budget', 'point', None], ['IMDB_Votes', 'Rotten_Tomatoes_Rating', 'Running_Time_min', 'rect', 'mean'], ['Production_Budget', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'Running_Time_min', 'Worldwide_Gross', 'point', None], ['US_Gross', 'Creative_Type', 'Running_Time_min', 'rect', 'mean'], ['Worldwide_Gross', 'Production_Budget', 'IMDB_Rating', 'rect', 'max']]
# [['Production_Budget', 'US_Gross', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Production_Budget', 'Running_Time_min', None, 'rect', 'count'], ['Running_Time_min', 'US_DVD_Sales', 'IMDB_Votes', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', 'IMDB_Votes', 'rect', 'mean'], ['Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'Creative_Type', 'point', None], ['Creative_Type', 'IMDB_Rating', None, 'bar', 'min']]
# [['Creative_Type', 'Production_Budget', None, 'arc', 'sum'], ['Rotten_Tomatoes_Rating', 'Production_Budget', 'Worldwide_Gross', 'rect', 'mean'], ['MPAA_Rating', 'US_DVD_Sales', None, 'bar', 'max'], ['Worldwide_Gross', 'Creative_Type', 'US_Gross', 'rect', 'max'], ['US_Gross', 'Running_Time_min', 'Creative_Type', 'point', None], ['Creative_Type', 'Rotten_Tomatoes_Rating', None, 'bar', 'min']]
# [['IMDB_Rating', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'Running_Time_min', 'Creative_Type', 'point', None], ['IMDB_Rating', 'US_Gross', 'Production_Budget', 'rect', 'mean'], ['US_Gross', 'IMDB_Votes', 'Production_Budget', 'rect', 'max'], ['US_DVD_Sales', 'MPAA_Rating', 'Production_Budget', 'rect', 'mean'], ['IMDB_Rating', 'US_Gross', 'Production_Budget', 'rect', 'mean']]
# [['Production_Budget', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Worldwide_Gross', 'US_DVD_Sales', 'Production_Budget', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Votes', 'Worldwide_Gross', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'point', None], ['IMDB_Votes', 'Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['US_Gross', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'mean']]
# [['US_DVD_Sales', 'Production_Budget', 'US_Gross', 'rect', 'mean'], ['Creative_Type', 'MPAA_Rating', None, 'rect', 'count'], ['Worldwide_Gross', 'Creative_Type', 'IMDB_Rating', 'rect', 'mean'], ['US_DVD_Sales', 'IMDB_Rating', 'Running_Time_min', 'point', None], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'point', None], ['US_DVD_Sales', 'IMDB_Votes', 'Production_Budget', 'point', None]]
# [['Creative_Type', 'MPAA_Rating', 'IMDB_Rating', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'mean'], ['US_DVD_Sales', 'Worldwide_Gross', 'Running_Time_min', 'rect', 'mean'], ['US_DVD_Sales', 'IMDB_Votes', 'Creative_Type', 'point', None], ['US_DVD_Sales', 'IMDB_Rating', 'Creative_Type', 'point', None], ['MPAA_Rating', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean']]
# [['IMDB_Votes', 'US_Gross', 'Worldwide_Gross', 'point', None], ['US_DVD_Sales', 'Creative_Type', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['MPAA_Rating', 'US_DVD_Sales', None, 'bar', 'min'], ['Rotten_Tomatoes_Rating', 'IMDB_Votes', 'Worldwide_Gross', 'rect', 'mean'], ['Creative_Type', 'IMDB_Votes', None, 'arc', 'min'], ['Worldwide_Gross', 'US_DVD_Sales', None, 'rect', 'count']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'IMDB_Rating', 'rect', 'mean'], ['Worldwide_Gross', 'Production_Budget', 'MPAA_Rating', 'point', None], ['Rotten_Tomatoes_Rating', 'Creative_Type', 'US_Gross', 'rect', 'mean'], ['Production_Budget', 'IMDB_Votes', 'Running_Time_min', 'point', None]]
# [['US_Gross', 'US_DVD_Sales', 'Worldwide_Gross', 'rect', 'mean'], ['MPAA_Rating', 'US_DVD_Sales', None, 'arc', 'mean'], ['IMDB_Rating', 'IMDB_Votes', 'MPAA_Rating', 'point', None], ['Rotten_Tomatoes_Rating', 'US_Gross', 'Creative_Type', 'point', None], ['Running_Time_min', 'US_DVD_Sales', 'Worldwide_Gross', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Rating', 'Production_Budget', 'rect', 'mean']]
# [['US_Gross', 'IMDB_Votes', 'US_DVD_Sales', 'point', None], ['US_DVD_Sales', 'Worldwide_Gross', 'Production_Budget', 'point', None], ['IMDB_Rating', 'Creative_Type', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'IMDB_Rating', 'Running_Time_min', 'point', None], ['Worldwide_Gross', 'US_DVD_Sales', 'IMDB_Votes', 'point', None]]
# [['IMDB_Votes', 'MPAA_Rating', 'IMDB_Rating', 'rect', 'max'], ['US_Gross', 'IMDB_Votes', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Creative_Type', 'IMDB_Rating', None, 'arc', 'mean'], ['Worldwide_Gross', 'Running_Time_min', 'Creative_Type', 'point', None], ['IMDB_Votes', 'US_DVD_Sales', 'Production_Budget', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'Creative_Type', 'point', None]]
# [['IMDB_Rating', 'Production_Budget', 'IMDB_Votes', 'point', None], ['Running_Time_min', 'MPAA_Rating', 'IMDB_Rating', 'rect', 'max'], ['Production_Budget', 'IMDB_Rating', 'US_Gross', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Votes', 'MPAA_Rating', 'point', None], ['IMDB_Rating', 'Production_Budget', 'Creative_Type', 'point', None], ['US_Gross', 'IMDB_Rating', 'Running_Time_min', 'point', None]]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'Creative_Type', 'Production_Budget', 'rect', 'max'], ['Running_Time_min', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Votes', 'Production_Budget', 'rect', 'mean'], ['IMDB_Rating', 'Running_Time_min', 'US_Gross', 'point', None], ['IMDB_Votes', 'US_Gross', 'US_DVD_Sales', 'rect', 'mean']]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'Running_Time_min', 'MPAA_Rating', 'point', None], ['IMDB_Rating', 'Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Running_Time_min', 'Production_Budget', 'US_DVD_Sales', 'point', None], ['US_DVD_Sales', 'Running_Time_min', 'US_Gross', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'Creative_Type', 'Production_Budget', 'rect', 'mean']]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Votes', 'Production_Budget', 'rect', 'mean'], ['Production_Budget', 'Running_Time_min', 'Creative_Type', 'point', None], ['Worldwide_Gross', 'MPAA_Rating', 'US_DVD_Sales', 'rect', 'max'], ['MPAA_Rating', 'Production_Budget', None, 'arc', 'min'], ['IMDB_Rating', 'IMDB_Votes', 'Worldwide_Gross', 'point', None]]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'Running_Time_min', 'IMDB_Rating', 'point', None], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'bar', 'mean'], ['Running_Time_min', 'Production_Budget', 'IMDB_Votes', 'point', None], ['IMDB_Votes', 'Production_Budget', 'Running_Time_min', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'US_Gross', 'IMDB_Votes', 'rect', 'mean']]
# [['Rotten_Tomatoes_Rating', 'Creative_Type', 'Worldwide_Gross', 'rect', 'mean'], ['IMDB_Rating', 'MPAA_Rating', 'US_DVD_Sales', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'US_DVD_Sales', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'US_Gross', 'rect', 'mean'], ['Worldwide_Gross', 'US_Gross', 'MPAA_Rating', 'point', None], ['Worldwide_Gross', 'Running_Time_min', 'Production_Budget', 'rect', 'mean']]
# [['US_Gross', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'rect', 'max'], ['US_Gross', 'Running_Time_min', 'IMDB_Rating', 'point', None], ['IMDB_Votes', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'max'], ['Worldwide_Gross', 'IMDB_Votes', 'Rotten_Tomatoes_Rating', 'point', None], ['US_Gross', 'Creative_Type', 'Worldwide_Gross', 'rect', 'max'], ['IMDB_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max']]
# [['US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Votes', 'Worldwide_Gross', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'US_DVD_Sales', 'Worldwide_Gross', 'rect', 'max'], ['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'US_Gross', 'rect', 'mean'], ['IMDB_Votes', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'point', None], ['Production_Budget', 'IMDB_Rating', 'Worldwide_Gross', 'rect', 'max']]
# [['IMDB_Rating', 'Worldwide_Gross', 'IMDB_Votes', 'point', None], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'rect', 'max'], ['Running_Time_min', 'Worldwide_Gross', 'Production_Budget', 'rect', 'max'], ['Creative_Type', 'IMDB_Rating', None, 'bar', 'sum'], ['US_DVD_Sales', 'IMDB_Rating', 'Running_Time_min', 'point', None], ['US_DVD_Sales', 'Creative_Type', 'Production_Budget', 'rect', 'mean']]
# [['Creative_Type', 'US_DVD_Sales', None, 'arc', 'max'], ['US_DVD_Sales', 'Worldwide_Gross', 'Running_Time_min', 'rect', 'mean'], ['US_Gross', 'IMDB_Votes', 'Running_Time_min', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Rating', 'IMDB_Votes', 'point', None], ['Production_Budget', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_DVD_Sales', 'Creative_Type', 'Running_Time_min', 'rect', 'mean']]
# [['IMDB_Votes', 'MPAA_Rating', 'US_Gross', 'rect', 'mean'], ['MPAA_Rating', 'US_Gross', None, 'bar', 'mean'], ['IMDB_Votes', 'US_Gross', 'Running_Time_min', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'Worldwide_Gross', 'rect', 'mean'], ['IMDB_Rating', 'Production_Budget', 'US_DVD_Sales', 'rect', 'mean'], ['Worldwide_Gross', 'US_DVD_Sales', 'IMDB_Rating', 'point', None]]
# [['US_Gross', 'IMDB_Votes', 'Running_Time_min', 'point', None], ['Production_Budget', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'point', None], ['Rotten_Tomatoes_Rating', 'US_Gross', 'Production_Budget', 'rect', 'max'], ['Running_Time_min', 'MPAA_Rating', 'Production_Budget', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'US_Gross', 'rect', 'max'], ['Running_Time_min', 'IMDB_Votes', 'Production_Budget', 'rect', 'max']]
# [['Production_Budget', 'Running_Time_min', 'Worldwide_Gross', 'point', None], ['US_Gross', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Creative_Type', 'MPAA_Rating', 'Production_Budget', 'rect', 'mean'], ['Running_Time_min', 'Production_Budget', 'Creative_Type', 'point', None], ['Rotten_Tomatoes_Rating', 'US_Gross', 'US_DVD_Sales', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'point', None]]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'US_DVD_Sales', 'IMDB_Votes', 'point', None], ['Production_Budget', 'IMDB_Rating', 'Running_Time_min', 'rect', 'mean'], ['Production_Budget', 'MPAA_Rating', 'US_DVD_Sales', 'rect', 'max'], ['Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'US_DVD_Sales', 'rect', 'max'], ['Worldwide_Gross', 'Production_Budget', 'IMDB_Votes', 'rect', 'mean']]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Rating', 'Production_Budget', 'MPAA_Rating', 'point', None], ['IMDB_Rating', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['US_DVD_Sales', 'US_Gross', None, 'rect', 'count'], ['IMDB_Rating', 'Running_Time_min', 'IMDB_Votes', 'point', None], ['Worldwide_Gross', 'IMDB_Rating', 'US_Gross', 'rect', 'mean']]
# [['US_Gross', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'rect', 'max'], ['Creative_Type', 'US_Gross', None, 'bar', 'max'], ['Worldwide_Gross', 'Production_Budget', 'US_Gross', 'point', None], ['Running_Time_min', 'Worldwide_Gross', 'US_Gross', 'rect', 'max'], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'Production_Budget', 'US_Gross', 'point', None]]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['Running_Time_min', 'Production_Budget', 'MPAA_Rating', 'point', None], ['Production_Budget', 'Creative_Type', 'US_DVD_Sales', 'rect', 'max'], ['Production_Budget', 'US_DVD_Sales', 'US_Gross', 'rect', 'mean'], ['IMDB_Rating', 'Running_Time_min', 'IMDB_Votes', 'point', None], ['MPAA_Rating', 'US_DVD_Sales', 'Creative_Type', 'bar', 'sum']]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'rect', 'max'], ['Creative_Type', 'US_Gross', None, 'arc', 'max'], ['US_DVD_Sales', 'US_Gross', 'Worldwide_Gross', 'point', None], ['Production_Budget', 'Running_Time_min', 'Worldwide_Gross', 'point', None], ['Worldwide_Gross', 'US_Gross', 'IMDB_Votes', 'point', None]]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['Running_Time_min', 'US_DVD_Sales', 'IMDB_Rating', 'rect', 'max'], ['US_Gross', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'point', None], ['US_DVD_Sales', 'Worldwide_Gross', 'IMDB_Rating', 'rect', 'mean'], ['Production_Budget', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['IMDB_Rating', 'US_DVD_Sales', 'MPAA_Rating', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_Gross', 'IMDB_Votes', 'Running_Time_min', 'rect', 'max'], ['US_Gross', 'Creative_Type', 'Worldwide_Gross', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Votes', 'Production_Budget', 'rect', 'mean'], ['Production_Budget', 'Creative_Type', 'Worldwide_Gross', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Rating', 'IMDB_Votes', 'rect', 'mean']]
# [['Running_Time_min', 'Worldwide_Gross', 'IMDB_Votes', 'point', None], ['Production_Budget', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'mean'], ['US_DVD_Sales', 'IMDB_Votes', 'IMDB_Rating', 'point', None], ['IMDB_Rating', 'US_DVD_Sales', 'Production_Budget', 'rect', 'mean'], ['US_Gross', 'IMDB_Votes', 'MPAA_Rating', 'point', None], ['Production_Budget', 'Worldwide_Gross', 'Running_Time_min', 'rect', 'max']]
# [['IMDB_Votes', 'Running_Time_min', 'US_Gross', 'rect', 'max'], ['US_DVD_Sales', 'MPAA_Rating', 'US_Gross', 'rect', 'max'], ['Running_Time_min', 'Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['MPAA_Rating', 'US_Gross', None, 'bar', 'max'], ['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'rect', 'mean'], ['US_DVD_Sales', 'Production_Budget', 'Worldwide_Gross', 'point', None]]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['US_Gross', 'Running_Time_min', 'IMDB_Rating', 'point', None], ['Production_Budget', 'US_Gross', 'IMDB_Rating', 'rect', 'mean'], ['US_DVD_Sales', 'IMDB_Rating', 'Running_Time_min', 'rect', 'mean'], ['IMDB_Votes', 'Creative_Type', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['MPAA_Rating', 'Creative_Type', 'US_Gross', 'rect', 'max']]
# [['Worldwide_Gross', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'max'], ['Worldwide_Gross', 'US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Running_Time_min', 'IMDB_Rating', 'Worldwide_Gross', 'rect', 'max'], ['US_Gross', 'IMDB_Votes', 'US_DVD_Sales', 'point', None], ['Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'US_DVD_Sales', 'point', None], ['Production_Budget', 'Creative_Type', 'US_Gross', 'rect', 'mean']]
# [['Production_Budget', 'US_DVD_Sales', 'Running_Time_min', 'rect', 'max'], ['IMDB_Votes', 'Production_Budget', 'Creative_Type', 'point', None], ['IMDB_Votes', 'Production_Budget', 'Running_Time_min', 'rect', 'mean'], ['Production_Budget', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'max'], ['Running_Time_min', 'US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'rect', 'max']]
# [['US_DVD_Sales', 'Running_Time_min', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'US_Gross', 'rect', 'max'], ['IMDB_Votes', 'Running_Time_min', 'Worldwide_Gross', 'point', None], ['Creative_Type', 'MPAA_Rating', 'US_DVD_Sales', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'US_DVD_Sales', 'rect', 'max'], ['Running_Time_min', 'Worldwide_Gross', 'US_Gross', 'rect', 'max']]
# [['Running_Time_min', 'US_Gross', 'Worldwide_Gross', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', 'Worldwide_Gross', 'rect', 'mean'], ['Production_Budget', 'Running_Time_min', 'US_Gross', 'point', None], ['Worldwide_Gross', 'IMDB_Rating', 'Running_Time_min', 'rect', 'mean'], ['Worldwide_Gross', 'US_DVD_Sales', 'US_Gross', 'rect', 'mean'], ['Creative_Type', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'mean']]
# [['Production_Budget', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Worldwide_Gross', 'Running_Time_min', 'US_DVD_Sales', 'rect', 'mean'], ['US_Gross', 'Running_Time_min', 'IMDB_Votes', 'point', None], ['US_DVD_Sales', 'IMDB_Votes', 'Production_Budget', 'rect', 'mean'], ['IMDB_Rating', 'US_Gross', 'Production_Budget', 'rect', 'mean'], ['Creative_Type', 'US_Gross', None, 'bar', 'mean']]
# [['Creative_Type', 'IMDB_Rating', None, 'arc', 'mean'], ['Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Rating', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Votes', 'Production_Budget', 'rect', 'mean'], ['US_Gross', 'US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'IMDB_Rating', 'Worldwide_Gross', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'US_DVD_Sales', 'US_Gross', 'point', None], ['US_DVD_Sales', 'IMDB_Rating', 'IMDB_Votes', 'rect', 'mean'], ['IMDB_Rating', 'Running_Time_min', 'US_DVD_Sales', 'rect', 'max'], ['IMDB_Votes', 'Worldwide_Gross', 'Running_Time_min', 'rect', 'mean'], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'Rotten_Tomatoes_Rating', 'US_Gross', 'point', None], ['IMDB_Votes', 'Worldwide_Gross', 'Production_Budget', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'Running_Time_min', 'US_DVD_Sales', 'point', None], ['Production_Budget', 'IMDB_Rating', 'Worldwide_Gross', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Worldwide_Gross', 'Running_Time_min', 'US_DVD_Sales', 'rect', 'mean'], ['Running_Time_min', 'US_DVD_Sales', 'Production_Budget', 'rect', 'max'], ['IMDB_Rating', 'US_Gross', 'US_DVD_Sales', 'point', None], ['Worldwide_Gross', 'Creative_Type', 'Running_Time_min', 'rect', 'max'], ['Worldwide_Gross', 'Creative_Type', 'Production_Budget', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Rating', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'max'], ['MPAA_Rating', 'Worldwide_Gross', None, 'arc', 'min'], ['US_Gross', 'US_DVD_Sales', 'Running_Time_min', 'rect', 'mean'], ['Running_Time_min', 'Production_Budget', 'MPAA_Rating', 'point', None], ['Rotten_Tomatoes_Rating', 'Production_Budget', 'US_DVD_Sales', 'rect', 'mean']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Rating', 'Running_Time_min', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'IMDB_Rating', 'rect', 'mean'], ['IMDB_Rating', 'Production_Budget', 'IMDB_Votes', 'rect', 'mean'], ['IMDB_Rating', 'US_DVD_Sales', 'Creative_Type', 'point', None], ['Production_Budget', 'US_DVD_Sales', 'IMDB_Votes', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Production_Budget', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'max'], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'US_Gross', 'point', None], ['Worldwide_Gross', 'MPAA_Rating', 'Running_Time_min', 'rect', 'mean'], ['US_DVD_Sales', 'Creative_Type', 'US_Gross', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'US_Gross', 'Running_Time_min', 'rect', 'mean'], ['IMDB_Rating', 'MPAA_Rating', None, 'bar', 'count'], ['Running_Time_min', 'Creative_Type', 'IMDB_Rating', 'rect', 'max'], ['Running_Time_min', 'Production_Budget', 'IMDB_Rating', 'rect', 'max'], ['Worldwide_Gross', 'IMDB_Votes', 'Production_Budget', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Votes', 'US_DVD_Sales', 'rect', 'max'], ['Running_Time_min', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'max'], ['Running_Time_min', 'Production_Budget', 'US_DVD_Sales', 'point', None], ['US_Gross', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Rating', 'IMDB_Votes', 'Production_Budget', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'IMDB_Rating', 'Running_Time_min', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'US_DVD_Sales', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'point', None], ['Rotten_Tomatoes_Rating', 'IMDB_Votes', 'Running_Time_min', 'point', None], ['Production_Budget', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_DVD_Sales', 'Production_Budget', 'Creative_Type', 'point', None], ['IMDB_Rating', 'Worldwide_Gross', 'IMDB_Votes', 'rect', 'mean'], ['US_DVD_Sales', 'IMDB_Votes', 'Creative_Type', 'point', None], ['US_DVD_Sales', 'IMDB_Votes', 'Production_Budget', 'rect', 'max'], ['US_DVD_Sales', 'Worldwide_Gross', 'IMDB_Rating', 'rect', 'max']]
# [['Running_Time_min', 'Worldwide_Gross', 'IMDB_Votes', 'point', None], ['Creative_Type', 'Worldwide_Gross', None, 'arc', 'mean'], ['IMDB_Rating', 'Creative_Type', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['US_DVD_Sales', 'Creative_Type', 'IMDB_Rating', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', 'IMDB_Votes', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', 'Worldwide_Gross', 'point', None]]
# [['US_Gross', 'US_DVD_Sales', 'Worldwide_Gross', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'mean'], ['US_Gross', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'point', None], ['US_Gross', 'IMDB_Rating', 'MPAA_Rating', 'point', None], ['Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'Running_Time_min', 'rect', 'max'], ['Running_Time_min', 'IMDB_Rating', 'IMDB_Votes', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'Worldwide_Gross', 'US_DVD_Sales', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Votes', 'IMDB_Rating', 'point', None], ['IMDB_Votes', 'US_DVD_Sales', 'Creative_Type', 'point', None], ['Running_Time_min', 'Production_Budget', 'US_Gross', 'rect', 'max'], ['Production_Budget', 'Rotten_Tomatoes_Rating', 'US_DVD_Sales', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'US_Gross', 'IMDB_Votes', 'rect', 'max'], ['Worldwide_Gross', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'IMDB_Votes', 'IMDB_Rating', 'rect', 'max'], ['MPAA_Rating', 'Worldwide_Gross', None, 'bar', 'sum'], ['US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'MPAA_Rating', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Creative_Type', 'US_DVD_Sales', None, 'bar', 'min'], ['US_Gross', 'IMDB_Votes', 'IMDB_Rating', 'rect', 'max'], ['US_Gross', 'US_DVD_Sales', 'MPAA_Rating', 'point', None], ['US_Gross', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Votes', 'Creative_Type', 'point', None], ['Production_Budget', 'Worldwide_Gross', 'IMDB_Votes', 'point', None], ['Rotten_Tomatoes_Rating', 'IMDB_Votes', 'Worldwide_Gross', 'rect', 'mean'], ['IMDB_Rating', 'US_Gross', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'US_Gross', 'Running_Time_min', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_DVD_Sales', 'Rotten_Tomatoes_Rating', None, 'rect', 'count'], ['Production_Budget', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['Production_Budget', 'IMDB_Rating', 'IMDB_Votes', 'rect', 'mean'], ['Running_Time_min', 'US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['MPAA_Rating', 'US_Gross', None, 'bar', 'mean']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Production_Budget', 'Creative_Type', 'US_Gross', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Votes', 'Running_Time_min', 'point', None], ['IMDB_Votes', 'US_Gross', 'US_DVD_Sales', 'point', None], ['Production_Budget', 'Worldwide_Gross', 'Running_Time_min', 'point', None], ['Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'US_DVD_Sales', 'rect', 'mean']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Rating', 'Worldwide_Gross', 'point', None], ['US_DVD_Sales', 'IMDB_Rating', 'IMDB_Votes', 'point', None], ['US_Gross', 'US_DVD_Sales', 'Production_Budget', 'point', None], ['US_Gross', 'Worldwide_Gross', 'IMDB_Votes', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'US_Gross', 'point', None]]
# [['IMDB_Rating', 'US_DVD_Sales', 'Running_Time_min', 'point', None], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'rect', 'max'], ['IMDB_Rating', 'US_DVD_Sales', 'Production_Budget', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'US_DVD_Sales', 'Creative_Type', 'point', None], ['MPAA_Rating', 'Running_Time_min', None, 'bar', 'mean']]
# [['IMDB_Rating', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'Rotten_Tomatoes_Rating', 'US_Gross', 'point', None], ['IMDB_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'mean'], ['Running_Time_min', 'Creative_Type', 'US_DVD_Sales', 'rect', 'max'], ['Running_Time_min', 'Worldwide_Gross', 'Production_Budget', 'point', None], ['Creative_Type', 'Rotten_Tomatoes_Rating', None, 'bar', 'mean']]
# [['US_DVD_Sales', 'Running_Time_min', 'Creative_Type', 'point', None], ['IMDB_Votes', 'Rotten_Tomatoes_Rating', 'US_Gross', 'point', None], ['Worldwide_Gross', 'Running_Time_min', 'US_DVD_Sales', 'rect', 'max'], ['US_Gross', 'IMDB_Rating', None, 'rect', 'count'], ['IMDB_Rating', 'MPAA_Rating', 'Running_Time_min', 'rect', 'max'], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_DVD_Sales', 'MPAA_Rating', 'Running_Time_min', 'rect', 'mean'], ['MPAA_Rating', 'IMDB_Votes', None, 'bar', 'min'], ['MPAA_Rating', 'Creative_Type', 'Worldwide_Gross', 'rect', 'mean'], ['IMDB_Rating', 'Creative_Type', 'US_Gross', 'rect', 'mean'], ['Running_Time_min', 'Creative_Type', 'US_Gross', 'rect', 'mean']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'Running_Time_min', 'US_Gross', 'rect', 'mean'], ['IMDB_Rating', 'Running_Time_min', 'US_Gross', 'rect', 'max'], ['IMDB_Votes', 'Worldwide_Gross', 'IMDB_Rating', 'rect', 'max'], ['US_Gross', 'Creative_Type', 'IMDB_Votes', 'rect', 'mean'], ['Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'US_Gross', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'IMDB_Votes', 'US_DVD_Sales', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', 'IMDB_Rating', 'point', None], ['MPAA_Rating', 'Production_Budget', 'Creative_Type', 'bar', 'sum'], ['Worldwide_Gross', 'IMDB_Votes', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Production_Budget', 'Running_Time_min', 'Creative_Type', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_Gross', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'max'], ['IMDB_Votes', 'IMDB_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', None, 'rect', 'count'], ['Production_Budget', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Production_Budget', 'Worldwide_Gross', 'US_Gross', 'rect', 'max'], ['IMDB_Rating', 'IMDB_Votes', None, 'rect', 'count'], ['Rotten_Tomatoes_Rating', 'US_DVD_Sales', 'Creative_Type', 'point', None], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'arc', 'mean'], ['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', 'Running_Time_min', 'point', None], ['US_DVD_Sales', 'IMDB_Rating', 'Production_Budget', 'point', None], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'US_Gross', 'rect', 'mean'], ['Running_Time_min', 'Production_Budget', 'Worldwide_Gross', 'rect', 'max'], ['Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_Gross', 'IMDB_Votes', 'Running_Time_min', 'rect', 'max'], ['Worldwide_Gross', 'Running_Time_min', 'Production_Budget', 'rect', 'max'], ['US_DVD_Sales', 'Worldwide_Gross', 'IMDB_Rating', 'rect', 'mean'], ['Worldwide_Gross', 'US_DVD_Sales', 'Creative_Type', 'point', None], ['US_DVD_Sales', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Production_Budget', 'IMDB_Rating', 'US_Gross', 'rect', 'mean'], ['IMDB_Rating', 'Worldwide_Gross', 'US_DVD_Sales', 'point', None], ['Rotten_Tomatoes_Rating', 'US_DVD_Sales', 'US_Gross', 'rect', 'max'], ['US_DVD_Sales', 'Creative_Type', 'Worldwide_Gross', 'rect', 'max'], ['Production_Budget', 'Rotten_Tomatoes_Rating', 'US_Gross', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'Production_Budget', 'Worldwide_Gross', 'point', None], ['US_DVD_Sales', 'Running_Time_min', 'US_Gross', 'point', None], ['Production_Budget', 'IMDB_Rating', 'Worldwide_Gross', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'US_Gross', 'US_DVD_Sales', 'point', None], ['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'rect', 'mean']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_Gross', 'Rotten_Tomatoes_Rating', 'US_DVD_Sales', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'US_Gross', 'IMDB_Votes', 'point', None], ['US_Gross', 'IMDB_Votes', 'Running_Time_min', 'rect', 'mean'], ['Worldwide_Gross', 'Production_Budget', 'US_Gross', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Votes', 'Production_Budget', 'point', None]]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['US_DVD_Sales', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Worldwide_Gross', 'Production_Budget', 'Running_Time_min', 'rect', 'mean'], ['Running_Time_min', 'MPAA_Rating', 'IMDB_Rating', 'rect', 'max'], ['Production_Budget', 'Running_Time_min', 'Worldwide_Gross', 'rect', 'max'], ['IMDB_Rating', 'US_Gross', 'Worldwide_Gross', 'point', None]]
# [['IMDB_Rating', 'US_DVD_Sales', 'MPAA_Rating', 'point', None], ['US_Gross', 'IMDB_Votes', 'Production_Budget', 'point', None], ['US_Gross', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'point', None], ['Worldwide_Gross', 'Creative_Type', 'US_Gross', 'rect', 'mean'], ['Creative_Type', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['IMDB_Rating', 'IMDB_Votes', 'US_DVD_Sales', 'rect', 'max']]
# [['Creative_Type', 'MPAA_Rating', 'Running_Time_min', 'rect', 'mean'], ['US_DVD_Sales', 'Creative_Type', 'Worldwide_Gross', 'rect', 'max'], ['IMDB_Votes', 'US_Gross', 'Worldwide_Gross', 'rect', 'mean'], ['US_DVD_Sales', 'Running_Time_min', 'US_Gross', 'rect', 'max'], ['US_DVD_Sales', 'MPAA_Rating', 'Running_Time_min', 'rect', 'mean'], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'rect', 'mean']]
# [['IMDB_Rating', 'Running_Time_min', 'US_DVD_Sales', 'rect', 'max'], ['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'Running_Time_min', 'US_DVD_Sales', 'rect', 'mean'], ['US_Gross', 'Production_Budget', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Production_Budget', 'Worldwide_Gross', 'US_Gross', 'point', None], ['US_DVD_Sales', 'Production_Budget', None, 'rect', 'count']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Votes', 'Production_Budget', 'point', None], ['MPAA_Rating', 'Running_Time_min', None, 'arc', 'mean'], ['US_DVD_Sales', 'Worldwide_Gross', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'max'], ['US_Gross', 'MPAA_Rating', 'Running_Time_min', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Votes', 'US_Gross', 'point', None], ['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['IMDB_Votes', 'MPAA_Rating', 'US_Gross', 'rect', 'mean'], ['IMDB_Rating', 'Creative_Type', 'US_DVD_Sales', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'IMDB_Rating', 'Creative_Type', 'point', None], ['US_Gross', 'Worldwide_Gross', 'Production_Budget', 'rect', 'mean'], ['IMDB_Votes', 'Production_Budget', 'US_Gross', 'point', None], ['IMDB_Rating', 'US_Gross', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Production_Budget', 'Creative_Type', None, 'bar', 'count']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Votes', 'Creative_Type', 'point', None], ['Running_Time_min', 'Production_Budget', 'US_Gross', 'rect', 'mean'], ['Running_Time_min', 'US_DVD_Sales', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'IMDB_Rating', 'Worldwide_Gross', 'point', None], ['US_DVD_Sales', 'Rotten_Tomatoes_Rating', None, 'rect', 'count']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'Production_Budget', 'Worldwide_Gross', 'point', None], ['Worldwide_Gross', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['MPAA_Rating', 'Worldwide_Gross', None, 'arc', 'mean'], ['Rotten_Tomatoes_Rating', 'US_Gross', 'US_DVD_Sales', 'point', None], ['IMDB_Votes', 'Creative_Type', 'US_DVD_Sales', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Production_Budget', 'Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Running_Time_min', 'US_DVD_Sales', 'Worldwide_Gross', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Rating', 'Production_Budget', 'rect', 'max'], ['US_Gross', 'US_DVD_Sales', 'MPAA_Rating', 'point', None], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'bar', 'min']]
# [['IMDB_Votes', 'Production_Budget', 'Rotten_Tomatoes_Rating', 'point', None], ['US_Gross', 'Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'rect', 'max'], ['US_Gross', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'point', None], ['MPAA_Rating', 'Creative_Type', 'US_DVD_Sales', 'rect', 'max'], ['IMDB_Rating', 'US_DVD_Sales', 'Worldwide_Gross', 'point', None], ['Rotten_Tomatoes_Rating', 'US_DVD_Sales', 'Production_Budget', 'point', None]]
# [['IMDB_Rating', 'US_DVD_Sales', 'US_Gross', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'Creative_Type', 'point', None], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['IMDB_Rating', 'Production_Budget', 'US_Gross', 'point', None], ['US_Gross', 'Production_Budget', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Running_Time_min', 'IMDB_Votes', None, 'rect', 'count']]
# [['Running_Time_min', 'IMDB_Votes', 'US_Gross', 'point', None], ['MPAA_Rating', 'Creative_Type', 'Production_Budget', 'rect', 'max'], ['US_Gross', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'MPAA_Rating', 'US_Gross', 'rect', 'max'], ['Production_Budget', 'IMDB_Rating', 'Worldwide_Gross', 'rect', 'max'], ['US_Gross', 'Production_Budget', 'Rotten_Tomatoes_Rating', 'point', None]]
# [['Worldwide_Gross', 'Creative_Type', 'IMDB_Votes', 'rect', 'mean'], ['MPAA_Rating', 'Production_Budget', None, 'arc', 'min'], ['Running_Time_min', 'US_DVD_Sales', 'Creative_Type', 'point', None], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'max'], ['Production_Budget', 'IMDB_Rating', 'Running_Time_min', 'rect', 'max'], ['IMDB_Votes', 'Running_Time_min', 'Worldwide_Gross', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['IMDB_Votes', 'US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'point', None], ['Creative_Type', 'US_Gross', None, 'arc', 'max'], ['IMDB_Votes', 'Worldwide_Gross', 'Creative_Type', 'point', None], ['IMDB_Rating', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'Production_Budget', 'rect', 'max']]
# [['Running_Time_min', 'Creative_Type', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['MPAA_Rating', 'IMDB_Votes', 'Creative_Type', 'bar', 'sum'], ['Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'Creative_Type', 'point', None], ['US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'US_Gross', 'rect', 'max'], ['Worldwide_Gross', 'US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'point', None], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'Running_Time_min', 'rect', 'mean']]
# [['Running_Time_min', 'US_DVD_Sales', 'IMDB_Rating', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', 'IMDB_Votes', 'rect', 'mean'], ['US_DVD_Sales', 'Worldwide_Gross', 'Production_Budget', 'rect', 'mean'], ['Production_Budget', 'US_Gross', 'IMDB_Rating', 'rect', 'mean'], ['Production_Budget', 'US_Gross', 'IMDB_Rating', 'rect', 'mean'], ['IMDB_Rating', 'Creative_Type', 'Running_Time_min', 'rect', 'max']]
# [['US_DVD_Sales', 'US_Gross', 'Worldwide_Gross', 'rect', 'max'], ['US_DVD_Sales', 'Running_Time_min', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'Production_Budget', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Rating', 'US_Gross', 'rect', 'max'], ['Running_Time_min', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'max'], ['Production_Budget', 'US_DVD_Sales', 'IMDB_Rating', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Production_Budget', 'Creative_Type', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['IMDB_Votes', 'US_DVD_Sales', 'Worldwide_Gross', 'rect', 'mean'], ['IMDB_Rating', 'Production_Budget', 'MPAA_Rating', 'point', None], ['Worldwide_Gross', 'IMDB_Votes', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Running_Time_min', 'MPAA_Rating', 'US_Gross', 'rect', 'max']]
# [['US_Gross', 'Creative_Type', 'US_DVD_Sales', 'rect', 'mean'], ['Running_Time_min', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'mean'], ['Running_Time_min', 'Worldwide_Gross', 'IMDB_Votes', 'point', None], ['US_DVD_Sales', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['US_Gross', 'MPAA_Rating', 'IMDB_Rating', 'rect', 'mean'], ['Production_Budget', 'IMDB_Rating', 'Worldwide_Gross', 'rect', 'mean']]
# [['Worldwide_Gross', 'US_DVD_Sales', 'IMDB_Votes', 'rect', 'mean'], ['US_DVD_Sales', 'IMDB_Votes', 'Worldwide_Gross', 'rect', 'max'], ['Creative_Type', 'Running_Time_min', None, 'arc', 'sum'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Rating', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'MPAA_Rating', 'Production_Budget', 'rect', 'mean']]
# [['Running_Time_min', 'Production_Budget', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'Running_Time_min', 'Creative_Type', 'point', None], ['Rotten_Tomatoes_Rating', 'IMDB_Votes', 'Worldwide_Gross', 'rect', 'max'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['US_Gross', 'Worldwide_Gross', 'IMDB_Rating', 'rect', 'max'], ['MPAA_Rating', 'US_DVD_Sales', None, 'arc', 'max']]
# [['IMDB_Votes', 'US_Gross', 'Worldwide_Gross', 'point', None], ['US_DVD_Sales', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['Production_Budget', 'Running_Time_min', 'Creative_Type', 'point', None], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'Creative_Type', None, 'bar', 'count'], ['Production_Budget', 'US_DVD_Sales', 'IMDB_Votes', 'rect', 'max']]
# [['US_Gross', 'Rotten_Tomatoes_Rating', 'Running_Time_min', 'point', None], ['Worldwide_Gross', 'Rotten_Tomatoes_Rating', None, 'rect', 'count'], ['US_DVD_Sales', 'Running_Time_min', 'US_Gross', 'rect', 'max'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['Running_Time_min', 'Production_Budget', 'Worldwide_Gross', 'point', None], ['US_Gross', 'Creative_Type', 'IMDB_Rating', 'rect', 'max']]
# [['Running_Time_min', 'US_Gross', 'IMDB_Votes', 'rect', 'max'], ['Worldwide_Gross', 'US_Gross', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['US_DVD_Sales', 'Production_Budget', 'Running_Time_min', 'rect', 'max'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'IMDB_Rating', 'MPAA_Rating', 'point', None], ['MPAA_Rating', 'IMDB_Votes', None, 'arc', 'min']]
# [['US_DVD_Sales', 'Worldwide_Gross', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'Creative_Type', 'Production_Budget', 'rect', 'max'], ['IMDB_Votes', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['Running_Time_min', 'Creative_Type', None, 'bar', 'count'], ['US_DVD_Sales', 'Running_Time_min', None, 'rect', 'count']]
# [['Running_Time_min', 'Worldwide_Gross', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'US_DVD_Sales', 'point', None], ['Production_Budget', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'IMDB_Rating', 'Running_Time_min', 'rect', 'mean'], ['Creative_Type', 'IMDB_Rating', None, 'bar', 'min']]
# [['US_DVD_Sales', 'Rotten_Tomatoes_Rating', 'US_Gross', 'rect', 'mean'], ['Production_Budget', 'Worldwide_Gross', 'Creative_Type', 'point', None], ['Production_Budget', 'MPAA_Rating', None, 'bar', 'count'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'Production_Budget', 'US_DVD_Sales', 'point', None], ['IMDB_Votes', 'Production_Budget', 'IMDB_Rating', 'point', None]]
# [['US_DVD_Sales', 'IMDB_Rating', 'Worldwide_Gross', 'rect', 'max'], ['US_DVD_Sales', 'Running_Time_min', 'Worldwide_Gross', 'point', None], ['US_DVD_Sales', 'Worldwide_Gross', None, 'rect', 'count'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'Production_Budget', 'US_DVD_Sales', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Votes', 'US_Gross', 'rect', 'mean']]
# [['Worldwide_Gross', 'Running_Time_min', 'IMDB_Rating', 'point', None], ['Running_Time_min', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'IMDB_Votes', 'Worldwide_Gross', 'point', None], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['MPAA_Rating', 'IMDB_Rating', None, 'arc', 'min'], ['Production_Budget', 'Worldwide_Gross', 'Running_Time_min', 'rect', 'mean']]
# [['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'arc', 'mean'], ['Production_Budget', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['Production_Budget', 'US_DVD_Sales', 'Worldwide_Gross', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'MPAA_Rating', 'Production_Budget', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'US_DVD_Sales', 'rect', 'max']]
# [['Running_Time_min', 'IMDB_Votes', 'IMDB_Rating', 'point', None], ['US_Gross', 'Rotten_Tomatoes_Rating', None, 'rect', 'count'], ['Running_Time_min', 'Worldwide_Gross', 'MPAA_Rating', 'point', None], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['US_Gross', 'MPAA_Rating', 'IMDB_Votes', 'rect', 'mean'], ['Worldwide_Gross', 'US_DVD_Sales', None, 'rect', 'count']]
# [['IMDB_Rating', 'US_Gross', 'Production_Budget', 'rect', 'max'], ['Running_Time_min', 'IMDB_Rating', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'Worldwide_Gross', 'IMDB_Rating', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['US_Gross', 'Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['US_Gross', 'Worldwide_Gross', 'IMDB_Rating', 'rect', 'max']]
# [['Running_Time_min', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'point', None], ['IMDB_Votes', 'Worldwide_Gross', 'US_DVD_Sales', 'rect', 'mean'], ['Rotten_Tomatoes_Rating', 'IMDB_Rating', 'Worldwide_Gross', 'point', None], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'Production_Budget', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Rating', 'US_Gross', 'point', None]]
# [['IMDB_Rating', 'US_DVD_Sales', 'MPAA_Rating', 'point', None], ['Production_Budget', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'US_Gross', 'point', None], ['Worldwide_Gross', 'IMDB_Votes', 'Rotten_Tomatoes_Rating', 'point', None], ['Production_Budget', 'Creative_Type', 'IMDB_Rating', 'rect', 'mean'], ['Worldwide_Gross', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'max']]
# [['Rotten_Tomatoes_Rating', 'IMDB_Votes', 'Running_Time_min', 'rect', 'max'], ['IMDB_Rating', 'Production_Budget', 'Running_Time_min', 'rect', 'mean'], ['Running_Time_min', 'IMDB_Votes', 'Creative_Type', 'point', None], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'Production_Budget', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'rect', 'mean']]
# [['Creative_Type', 'US_Gross', None, 'arc', 'mean'], ['Running_Time_min', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'point', None], ['US_Gross', 'Creative_Type', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'rect', 'max'], ['Production_Budget', 'Worldwide_Gross', 'IMDB_Rating', 'point', None]]
# [['Rotten_Tomatoes_Rating', 'IMDB_Rating', 'US_DVD_Sales', 'rect', 'max'], ['IMDB_Votes', 'MPAA_Rating', 'Production_Budget', 'rect', 'mean'], ['IMDB_Rating', 'Production_Budget', 'Rotten_Tomatoes_Rating', 'point', None], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['IMDB_Votes', 'US_DVD_Sales', 'Running_Time_min', 'rect', 'mean'], ['IMDB_Rating', 'IMDB_Votes', 'Production_Budget', 'rect', 'max']]
# [['Running_Time_min', 'Production_Budget', 'IMDB_Votes', 'rect', 'max'], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'bar', 'sum'], ['US_DVD_Sales', 'MPAA_Rating', 'Rotten_Tomatoes_Rating', 'rect', 'mean'], ['US_DVD_Sales', 'IMDB_Votes', 'Production_Budget', 'rect', 'mean'], ['IMDB_Votes', 'Running_Time_min', 'US_DVD_Sales', 'point', None], ['IMDB_Rating', 'US_DVD_Sales', 'Worldwide_Gross', 'point', None]]
# [['Production_Budget', 'US_DVD_Sales', 'Running_Time_min', 'rect', 'max'], ['US_Gross', 'Creative_Type', 'Worldwide_Gross', 'rect', 'max'], ['US_Gross', 'MPAA_Rating', None, 'bar', 'count'], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['US_Gross', 'Production_Budget', 'IMDB_Votes', 'point', None]]
# [['IMDB_Votes', 'Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'rect', 'mean'], ['US_Gross', 'Rotten_Tomatoes_Rating', None, 'rect', 'count'], ['US_DVD_Sales', 'Worldwide_Gross', 'MPAA_Rating', 'point', None], ['MPAA_Rating', 'Creative_Type', 'IMDB_Votes', 'rect', 'max'], ['US_DVD_Sales', 'IMDB_Rating', 'US_Gross', 'point', None], ['Production_Budget', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'point', None]]
# ...
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1261346963)]
#         space: Space([Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                       Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                       Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                       Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                       Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                       Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None)])
#  random_state: RandomState(MT19937)
#         specs:     args:              dimensions: Space([Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                                                          Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                                                          Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                                                          Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                                                          Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None),
#                                                          Categorical(categories=('["US_Gross", "Worldwide_Gross", null, "rect", "count"]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "point", null]', '["US_Gross", "Worldwide_Gross", "US_DVD_Sales", "rect", "mean"]', ..., '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "point", null]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "mean"]', '["IMDB_Votes", "IMDB_Rating", "Rotten_Tomatoes_Rating", "rect", "max"]'), prior=None)])
#                                   base_estimator: gp
#                                  n_random_starts: None
#                                 n_initial_points: 10
#                          initial_point_generator: random
#                                           n_jobs: 1
#                                         acq_func: gp_hedge
#                                    acq_optimizer: auto
#                                     random_state: None
#                                 model_queue_size: None
#                                  acq_func_kwargs: None
#                             acq_optimizer_kwargs: None
#                function: Optimizer

# %%
opt_cat = Optimizer(opt_space, random_state=42, base_estimator="GP", acq_func="EI")
n = 0
for i in range(50):
    dashboard: list[ProbabilisticNode] = []
    xs = []
    while len(dashboard) < NUM_CHARTS:
        x = opt_space.rvs()[0]
        checker = [dic[attr] for attr in x[:3]] + [x[3], x[4]]
        for chart in chart_map:
            if all([checker[i] == chart[i] for i in range(5)]) and len(checker) == len(set(checker)):
                xs.append(x)
                dashboard.append(prob.get_node(x))
                break
    score = prob.infer(dashboard, oracle, ["attr_IMDB_Votes", "rect"])
    opt_cat.tell(xs, [-score for _ in range(NUM_CHARTS)])

# %%
opt_cat.get_result()
# Out:
#           fun: -1.9733068783068781
#             x: ['Creative_Type', 'IMDB_Votes', None, 'bar', 'sum']
#     func_vals: [-1.467e+00 -1.467e+00 ... -1.464e+00 -1.464e+00]
#       x_iters: [['MPAA_Rating', 'US_DVD_Sales', None, 'arc', 'min'], ['Rotten_Tomatoes_Rating', 'Creative_Type', None, 'bar', 'count'], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'bar', 'sum'], ['MPAA_Rating', 'Worldwide_Gross', None, 'arc', 'mean'], ['Production_Budget', 'MPAA_Rating', None, 'bar', 'count'], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'bar', 'min'], ['MPAA_Rating', 'IMDB_Rating', None, 'bar', 'sum'], ['MPAA_Rating', 'US_Gross', None, 'arc', 'max'], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'bar', 'max'], ['Creative_Type', 'Worldwide_Gross', None, 'bar', 'mean'], ['MPAA_Rating', 'Production_Budget', None, 'bar', 'min'], ['Creative_Type', 'Rotten_Tomatoes_Rating', None, 'arc', 'max'], ['Creative_Type', 'IMDB_Rating', None, 'bar', 'mean'], ['MPAA_Rating', 'Worldwide_Gross', None, 'bar', 'mean'], ['MPAA_Rating', 'Production_Budget', None, 'bar', 'max'], ['MPAA_Rating', 'Worldwide_Gross', None, 'arc', 'mean'], ['MPAA_Rating', 'Production_Budget', None, 'bar', 'mean'], ['Creative_Type', 'Worldwide_Gross', None, 'arc', 'mean'], ['Production_Budget', 'Creative_Type', None, 'bar', 'count'], ['MPAA_Rating', 'Running_Time_min', None, 'arc', 'max'], ['MPAA_Rating', 'IMDB_Rating', None, 'bar', 'mean'], ['Running_Time_min', 'Creative_Type', None, 'bar', 'count'], ['Rotten_Tomatoes_Rating', 'MPAA_Rating', None, 'bar', 'count'], ['MPAA_Rating', 'US_Gross', None, 'bar', 'sum'], ['MPAA_Rating', 'IMDB_Rating', None, 'bar', 'max'], ['MPAA_Rating', 'Running_Time_min', None, 'arc', 'mean'], ['MPAA_Rating', 'IMDB_Votes', None, 'arc', 'max'], ['Creative_Type', 'US_DVD_Sales', None, 'bar', 'mean'], ['MPAA_Rating', 'US_Gross', None, 'arc', 'min'], ['Running_Time_min', 'MPAA_Rating', None, 'bar', 'count'], ['MPAA_Rating', 'Production_Budget', None, 'bar', 'mean'], ['MPAA_Rating', 'Production_Budget', None, 'arc', 'max'], ['US_Gross', 'Creative_Type', None, 'bar', 'count'], ['MPAA_Rating', 'Production_Budget', None, 'arc', 'mean'], ['Creative_Type', 'Running_Time_min', None, 'bar', 'mean'], ['MPAA_Rating', 'Running_Time_min', None, 'bar', 'sum'], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'arc', 'mean'], ['Creative_Type', 'US_Gross', None, 'bar', 'min'], ['Creative_Type', 'Running_Time_min', None, 'bar', 'min'], ['MPAA_Rating', 'IMDB_Votes', None, 'bar', 'mean'], ['MPAA_Rating', 'Production_Budget', None, 'bar', 'min'], ['Creative_Type', 'Running_Time_min', None, 'bar', 'sum'], ['Production_Budget', 'Creative_Type', None, 'bar', 'count'], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'bar', 'max'], ['US_DVD_Sales', 'Creative_Type', None, 'bar', 'count'], ['MPAA_Rating', 'US_Gross', None, 'bar', 'min'], ['MPAA_Rating', 'Running_Time_min', None, 'bar', 'max'], ['MPAA_Rating', 'Worldwide_Gross', None, 'bar', 'sum'], ['Creative_Type', 'Production_Budget', None, 'arc', 'mean'], ['Creative_Type', 'IMDB_Rating', None, 'bar', 'min'], ['Creative_Type', 'US_Gross', None, 'bar', 'mean'], ['MPAA_Rating', 'IMDB_Rating', None, 'bar', 'max'], ['Creative_Type', 'US_Gross', None, 'arc', 'mean'], ['Creative_Type', 'Worldwide_Gross', None, 'bar', 'max'], ['MPAA_Rating', 'Worldwide_Gross', None, 'bar', 'max'], ['MPAA_Rating', 'US_DVD_Sales', None, 'arc', 'mean'], ['MPAA_Rating', 'Rotten_Tomatoes_Rating', None, 'bar', 'sum'], ['MPAA_Rating', 'US_Gross', None, 'bar', 'sum'], ['MPAA_Rating', 'IMDB_Rating', None, 'bar', 'mean'], ['MPAA_Rating', 'Production_Budget', None, 'arc', 'min'], ['Production_Budget', 'Creative_Type', None, 'bar', 'count'], ['MPAA_Rating', 'Production_Budget', None, 'bar', 'max'], ['MPAA_Rating', 'Production_Budget', None, 'bar', 'mean'], ['MPAA_Rating', 'Production_Budget', None, 'arc', 'min'], ['Creative_Type', 'US_Gross', None, 'bar', 'mean'], ['Creative_Type', 'Worldwide_Gross', None, 'arc', 'max'], ['Creative_Type', 'Running_Time_min', None, 'bar', 'max'], ['MPAA_Rating', 'IMDB_Rating', None, 'arc', 'min'], ['Creative_Type', 'Running_Time_min', None, 'arc', 'mean'], ['MPAA_Rating', 'Running_Time_min', None, 'ba ...
#        models: [GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * HammingKernel(0, 0, 0, 0, 0) + WhiteKernel(noise_level=1),
#                                         n_restarts_optimizer=2, noise='gaussian',
#                                         normalize_y=True, random_state=1608637542)]
#         space: Space([Categorical(categories=('US_Gross', 'Worldwide_Gross', 'US_DVD_Sales', ..., 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes'), prior=None),
#                       Categorical(categories=(None, 'US_Gross', 'Worldwide_Gross', ..., 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes'), prior=None),
#                       Categorical(categories=(None, 'US_Gross', 'Worldwide_Gross', ..., 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes'), prior=None),
#                       Categorical(categories=('bar', 'point', 'arc', 'rect', 'tick', 'boxplot'), prior=None),
#                       Categorical(categories=(None, 'mean', 'max', 'sum', 'min', 'count'), prior=None)])
#  random_state: RandomState(MT19937)
#         specs:     args:              dimensions: Space([Categorical(categories=('US_Gross', 'Worldwide_Gross', 'US_DVD_Sales', ..., 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes'), prior=None),
#                                                          Categorical(categories=(None, 'US_Gross', 'Worldwide_Gross', ..., 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes'), prior=None),
#                                                          Categorical(categories=(None, 'US_Gross', 'Worldwide_Gross', ..., 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes'), prior=None),
#                                                          Categorical(categories=('bar', 'point', 'arc', 'rect', 'tick', 'boxplot'), prior=None),
#                                                          Categorical(categories=(None, 'mean', 'max', 'sum', 'min', 'count'), prior=None)])
#                                   base_estimator: GP
#                                  n_random_starts: None
#                                 n_initial_points: 10
#                          initial_point_generator: random
#                                           n_jobs: 1
#                                         acq_func: EI
#                                    acq_optimizer: auto
#                                     random_state: 42
#                                 model_queue_size: None
#                                  acq_func_kwargs: None
#                             acq_optimizer_kwargs: None
#                function: Optimizer

# %%
def func_cat(x):
    return -prob.infer(x, oracle, ["attr_IMDB_Votes", "rect"])
    
    
for i in range(100):
    x = opt_cat.ask(n_points=6)
    processed_x = [prob.get_node(sample) for sample in x]
    y = func_cat(processed_x)
    opt_cat.tell(processed_x, y)

# %%
from skopt import Optimizer
from skopt.space import Space, Real
from IPython.display import clear_output

attrs = [None] + name_attrs

x = [Real(0.01, 1.0, name=f"x{i}") for i in range(len(attrs[1:]))]
y = [Real(0.01, 1.0, name=f"y{i}") for i in range(len(attrs))]
z = [Real(0.01, 1.0, name=f"z{i}") for i in range(len(attrs))]
ct = [Real(0.01, 1.0, name=f"ct{i}") for i in range(len(chart_type))]
at = [Real(0.01, 1.0, name=f"at{i}") for i in range(len(agg_type))]


opt_weight = Space([
    *x, *y, *z, *ct, *at
])


opt = Optimizer(opt_weight, base_estimator="GP" ,n_initial_points=10, acq_func="EI")


weights = []

for i in range(100):
    params = opt.ask()
    x = np.array(params)
    weight = SamplingWeight(
        x=x[0 : len(attrs) - 1],
        y=x[len(attrs) - 1 : 2 * len(attrs) - 1],
        z=x[2 * len(attrs) - 1 : 3 * len(attrs) - 1],
        ct=x[3 * len(attrs) - 1 : 3 * len(attrs) - 1 + len(chart_type)],
        at=x[3 * len(attrs) - 1 + len(chart_type) :],
        attr=attrs,
        chart_type=chart_type,
        agg_type=agg_type
    )
    
    weights.append(weight)
    
    # clear_output(wait=True)
    # display(weight.visualize())
    y = func_max(weight, 6)
    opt.tell(params, y)

# %%
print(opt.get_result())
func_vals = opt.get_result().func_vals
print(np.argmin(func_vals), np.min(func_vals))

# %%
import altair as alt

x = {
    chart_type[i] : [w.ct[i] for w in weights]
    for i in range(len(chart_type))
}

x["epoch"] = list(range(len(weights)))
x["func_vals"] = [-w for w in opt.get_result().func_vals]

data = pd.DataFrame.from_dict(x)
data.head()

# %%
max_weight = weights[np.argmin(func_vals)]

max_weight.visualize()

# %%
chart = alt.Chart(data).mark_line().encode(
    x="epoch",
    y=alt.Y(alt.repeat("row"), type="quantitative"),
    color=alt.datum(alt.repeat("row"))
).properties(width=900).repeat(row=["func_vals"]+chart_type)
chart

# %%
func(max_weight, 6, 50)
func(SamplingWeight(
    attr=attrs,
    chart_type=chart_type,
    agg_type=agg_type,
    x=np.ones(len(attrs) - 1) / (len(attrs) - 1),
    y=np.ones(len(attrs)) / len(attrs),
    z=np.ones(len(attrs)) / len(attrs),
    ct=np.ones(len(chart_type)) / len(chart_type),
    at=np.ones(len(agg_type)) / len(agg_type),
), 6, 50)
